# %% [markdown]
# # 🚀 AlphaEdge - 20-Year Veteran AI Trading Terminal (Google Colab Cloud Runner)
#
# Run AlphaEdge completely in the cloud on Google's 12 GB RAM cloud servers with **0% load on your PC**.
#
# ### Instructions:
# 1. Click **Runtime** -> **Run all** (or press `Ctrl + F9`).
# 2. Click the public **Cloudflare Tunnel** URL (`.trycloudflare.com`) printed below to open your terminal!
# *(Cloudflare Tunnel permanently prevents HTTP 502 Bad Gateway timeouts, connection drops, and password prompts).*

# %%
# Step 1: Clone repo and install requirements
# !rm -rf /content/Trader
# !git clone https://github.com/mrmadhav0973/Trader.git /content/Trader
# %cd /content/Trader
# !pip install -q -r requirements.txt

# Step 2: Start AlphaEdge server in background
import subprocess
import time

print("⚡ Starting AlphaEdge FastAPI Server on Google Cloud...")
proc = subprocess.Popen(["python", "-m", "uvicorn", "server:app", "--host", "0.0.0.0", "--port", "8000"])
time.sleep(3)

# Step 3: Launch Enterprise Cloudflare Tunnel (Eliminates 502 Bad Gateway & Drops)
print("🌐 Setting up Cloudflare High-Speed Tunnel...")
# !wget -q -nc https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb > /dev/null 2>&1

print("\n" + "="*65)
print("🚀 YOUR ULTRA-STABLE CLOUDFLARE LINK IS STARTING BELOW:")
print("(Click the url ending in .trycloudflare.com)")
print("="*65 + "\n")

# !cloudflared tunnel --url http://127.0.0.1:8000

# %% [markdown]
# ### 💡 Alternative Backup Tunnel (Localtunnel)
# If you ever prefer localtunnel, stop the cell above and run the cell below:

# %%
# !npx localtunnel --port 8000
